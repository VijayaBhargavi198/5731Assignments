# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayaBhargavi198/5731Assignments/blob/master/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/16/2020, 20 points in total)

# %% [markdown]
# The purpose of this exercise is to under users' information needs, then collect the data for analysis.

# %% [markdown]
# Question 1 (8 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

# %% [markdown]
# Research question:
# Current topic thats everywhere is corona, so i intend to work on corona updates website and I intend to scrape the website and get details about the countries and their current corona virus infections and deaths and effects of corona on each country.
# Data is collected from the website https://www.worldometers.info/coronavirus/ , it  is currently the most updated website on corona data.
#
# How much data needed for the analysis?
# My idea of analysis is to scrape data from this website and get information about every country that’s effected and later analysis could go on the grounds as to which country is most effected and what are the common causes that could have increased the spread in the countries etc.
# For now, The considered data has every country as the row and gives details like new cases, new deaths, total number of cases, total number of deaths and ratio of cases, ratio of deaths and population etc.
#
# The detail steps for collecting and save the data.
# 1.	Actually, we try to understand the website as the first step.see what data we have, if tables are used in the website then what rows and columns we have.
# 2.  once thats done, we should import the required libraries.
# 3.	Use beautiful soup and read the page,'User-Agent':'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7',was used to surpass restrictions.
# 4.	Every web item would have tags,we should understand and identify which tag is corresponding to which item of the website.
# 5.	Try to call and extract data using these identified tags.
# 6.	Now once we identify and call the data, it is good to display but cannot be stored, for storing we used data frames. we need to store all the extracted data into data frames (pandas was used)
# 7.	Displaying data as per required using the data frames.

# %% [markdown]
# Question 2 (12 points): Write python code to collect 500 items of the data you plan to collect above.

# %%
# You code here (Please add comments in the code):

import pandas as pd
from bs4 import BeautifulSoup
import urllib
import requests

# %%
page = urllib.request.urlopen(urllib.request.Request("https://www.worldometers.info/coronavirus/",None,{'User-Agent':'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7',}))

soup = BeautifulSoup(page)
# print(soup.prettify)

# %%
data_table = soup.find_all("tr",{"style":""})
number = soup.find_all("td",{"style":"font-size:12px;color: grey;text-align:center;vertical-align:middle;"})
country = soup.find_all("a",{"class":"mt_a"})
# total_cases = soup.find_all("td",{"style":"font-weight: bold; font-size:15px; text-align:left;"})
newCases = soup.find_all("td",{"style":"font-weight: bold; text-align:right;background-color:#FFEEAA;"})
totalDeaths = soup.find_all("td",{"style":"font-weight: bold; text-align:right;"})
newDeaths = soup.find_all("td",{"style":"font-weight: bold; \n                                    text-align:right;background-color:red; color:white"})
list_of_values = soup.find_all("td",{"style":"font-weight: bold; text-align:right"})
#print(list_of_values)
activeCases = soup.find_all("td",{"style":"text-align:right;font-weight:bold;"})
values = list()

# %%
#-------------------------------------------------

numbers_l = list()
country_names =list()
total_recovered = list()
serious_or_critical = list()
tot_cases_1mpop = list()
deaths_1Mpop = list()
total_tests = list()
tests_1Mpop = list()
population=list()
total_cases = list()
new_cases = list()
total_deaths = list()
new_deaths =list()
active_cases = list()
for i in list_of_values:
  values.append(i.text)

for i in range(0,len(values),8):
  total_cases.append(values[i])
  total_recovered.append(values[i+1])
  serious_or_critical.append(values[i+2])
  tot_cases_1mpop.append(values[i+3])
  deaths_1Mpop.append(values[i+4])
  total_tests.append(values[i+5])
  tests_1Mpop.append(values[i+6])
  population.append(values[i+7])


for i,c,n,t,nd,ac in zip(number,country,newCases,totalDeaths,newDeaths,activeCases):
  numbers_l.append(i.text)
  country_names.append(c.text)
  new_cases.append(n.text)
  total_deaths.append(t.text)
  new_deaths.append(nd.text)
  active_cases.append(ac.text)

ouputDF = pd.DataFrame(list(zip(country_names,total_cases,new_cases,total_deaths,new_deaths,total_recovered,active_cases,serious_or_critical,tot_cases_1mpop,deaths_1Mpop,total_tests,tests_1Mpop,population)),\
                       columns = ['country','total_cases','new_cases','total_deaths','new_deaths','total_recovered','active_cases','serious_or_critical','total_cases_1m_Population','Deaths_For_1M_population','Total_Tests','Tests_for_1M_Population','Population'])

pd.set_option("display.max_rows", 500, "display.max_columns", 50) 
ouputDF
# Out:
#                     country total_cases new_cases total_deaths new_deaths  \
# 0                       USA   6,918,702   +44,106     203,071        +858
# 1                     India   5,305,475   +92,789      85,625      +1,221
# 2                    Brazil   4,495,183   +37,740     135,793        +762
# 3                    Russia   1,091,186    +5,905      19,195        +134
# 4                  Colombia     750,471    +6,526      23,850        +185
# 5                      Peru     750,098    +3,182                    +201
# 6                    Mexico     684,113    +4,697      31,146         +90
# 7                     Spain     659,334    +2,055                     +85
# 8              South Africa     657,627    +1,677      72,179         +31
# 9                 Argentina     601,713   +13,215      30,495         +57
# 10                    Chile     442,827    +3,049          N/A       +154
# 11                   France     428,696    +4,322      15,857        +144
# ...
